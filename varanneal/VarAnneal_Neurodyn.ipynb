# %% [markdown]
# # VarAnneal tutorial

# %% [markdown]
# VarAnneal is a Python package for state and parameter estimation in partially observed dynamical systems and neural networks.  It uses variational annealing (VA), a variational data assimilation method.
#
# VA uses numerical optimization to estimate path-space statistics given by high-dimensional integrals of the form:
# $$
# \mathrm{E}\left[G(X) \lvert Y\right] = \frac{\int dX \: G(X)\: e^{-A(X,Y)}}{\int dX \: e^{-A(X,Y)}} \equiv \frac{1}{\mathcal{Z}(Y)} \int dX \: G(X)\: e^{-A(X,Y)}
# $$
# where $X$ is a vector of model states and parameters, and $Y$ is a vector of observational data.  Optimization is carried out using one of a variety of methods, such as L-BFGS-B, NCG, IPOPT (future), ...   These methods require derivatives of $A$, which are computed using automatic differentiation.
#
# In dynamical systems, this amounts to estimating statistics for model parameters, as well as trajectories of model states, like the mode, mean, variance, ...  The data consists of time series of partial observations of the model variables.
#
# In neural networks, this is used as a method of training the network weights on labeled data sets.
#
# ---

# %%
import numpy as np
from scipy import interpolate
from varanneal import va_ode
import pickle
import os, time

# %%
import matplotlib
matplotlib.use('nbagg')
import matplotlib.pyplot as plt
import matplotlib.colors as mplcolors

from matplotlib import gridspec

# For 3D plots
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# %%
from varanneal import va_ode

# %% [markdown]
# ## Define the ODE system

# %% [markdown]
# Load in the input current

# %%
Ipath = os.getcwd() + "/IforRealNeuron.csv"
Idat = np.genfromtxt(Ipath, delimiter=',')

# %% [markdown]
# Set parameters

# %%
#Scaling Values
# The scale for V * C should match the scale for I
V_scale = 1 # V to V
C_scale = 1e9 # F to nF

# The scales for I * R should match the scale for V
I_scale = 1e9 # A to nA
R_scale = 1e-9 # O to ...

# %%
# Voltages
# Chip bias voltage
V_ref = 1 * V_scale
# Unit Volt(?)
V_unit = 26e-3 * V_scale

# Currents
# Master current(?)
I_master = 1.25e-9 * I_scale
# Voltage(?)
I_voltage = 230e-9 * I_scale
# Reference Current(?)
I_ref = 85e-9 * I_scale
# Injected current scale factor
I_inj_scale = (0.018) * 1e-9 * I_scale

# Capacitances
# Membrane Capacitance
C_m = 4e-12 * C_scale
# Gate capacitance
C_gate = 5e-12 * C_scale

# Resistances
Res = 1.63e6 * R_scale
R_bias = 1.85e6  * R_scale
R_factor = 700e3 * R_scale
R_factor2 = 50e3 * R_scale

# Scale Factors
kappa = 0.7

# Hodgkin Huxley Parameters
g0 = [800, 160, 15] #maximal conductances
e_rev = [300, -210, -190] #reversal potentials in mV

# Scaling H-H parameters for chip
g = np.multiply(g0,(kappa / V_unit) * (I_master / 1024))
E_rev = np.multiply(e_rev,(I_voltage / 1024) * Res) + V_ref


# Conductance Dynamics
vBias = np.zeros(7)
vHigh = V_ref + R_bias * I_voltage
vLow = V_ref - R_bias * I_voltage
I_factor = (vHigh - vLow) / R_factor
vBias[0] = vLow + I_factor * R_factor2

for i in xrange(1,7):
    #[635.2, 756.8, 878.42, 1000, 1121.57, 1243.14, 1364.7] in mV
    vBias[i] = vBias[i - 1] + I_factor * 2*R_factor2 
    
g_f = 1 / (C_gate * V_unit) 
    
am = np.array([0, 0, 120, 400, 800, 1023, 1023]) * I_master / 1024 * g_f
bm = np.array([1023, 1023, 1023, 1023, 0, 0, 0]) * I_master / 1024 * g_f

ah = np.array([237, 80, 0, 0, 0, 0, 0]) * I_master / 1024 * g_f 
bh = np.array([0, 0, 0, 0, 41, 50, 70]) * I_master / 1024 * g_f

an = np.array([0, 0, 0, 0, 18, 5, 43]) * I_master / 1024 * g_f
bn = np.array([1, 0, 0, 1, 0, 0, 1]) * I_master / 1024 * g_f

# %%
#Wrapping up the parameters
model_params = []
model_params.append(g)
model_params.append(E_rev)
model_params.append(vBias)
model_params.append(am)
model_params.append(bm)
model_params.append(ah)
model_params.append(bh)
model_params.append(an)
model_params.append(bn)

# %%
# Load in the parameters
sf = np.load("neurodyn/scale_factors.npy")
with open("neurodyn/model_params.txt", "rb") as fp:
    model_params = pickle.load(fp)
    
# Unpack parameters
V_scale = sf[0]
C_scale = sf[1]
I_scale = sf[2]
I_inj_scale = sf[3]
R_scale = sf[4]

mp = model_params
C_m = 4e-12 * C_scale
g = mp[0]
E_rev = mp[1]
vBias = mp[2]
am = mp[3]
bm = mp[4]
ah = mp[5]
bh = mp[6]
an = mp[7]
bn = mp[8]

# %%
model_params
# Out:
# [array([ 26.29206731,   5.25841346,   0.49297626]),
#  array([ 1.10983398,  0.92311621,  0.93043848]),
#  array([ 0.63528571,  0.75685714,  0.87842857,  1.        ,  1.12157143,
#          1.24314286,  1.36471429]),
#  array([    0.        ,     0.        ,  1126.80288462,  3756.00961538,
#          7512.01923077,  9605.99459135,  9605.99459135]),
#  array([ 9605.99459135,  9605.99459135,  9605.99459135,  9605.99459135,
#             0.        ,     0.        ,     0.        ]),
#  array([ 2225.43569712,   751.20192308,     0.        ,     0.        ,
#             0.        ,     0.        ,     0.        ]),
#  array([   0.        ,    0.        ,    0.        ,    0.        ,
#          384.99098558,  469.50120192,  657.30168269]),
#  array([   0.        ,    0.        ,    0.        ,    0.        ,
#          169.02043269,   46.95012019,  403.77103365]),
#  array([ 9.39002404,  0.        ,  0.        ,  9.39002404,  0.        ,
#          0.        ,  9.39002404])]

# %% [markdown]
# Define alpha and beta representations

# %%
def sigma(vBiask, V, sign = 1):
    mu = 0.7
    Ut = 26e-3 * V_scale
    return 1 / (1 + np.exp(sign * mu * (vBiask - V) / Ut))


def alpha_spline(V, x, vBias=vBias, am=am, ah=ah, an=an):
    """
    Used to compute the conductance at each time point. 
    The optional arguments default to the parameters defined at the start of the document
    """
    alpha = 0
    for k in np.arange(7):
        if x == "m":
            alpha += am[k] * sigma(vBias[k], V, 1)
        if x == "h":
            alpha += ah[k] * sigma(vBias[k], V, -1)
        if x == "n":
            alpha += an[k] * sigma(vBias[k], V, 1)
    return alpha


def beta_spline(V, x, vBias=vBias, bm=bm, bh=bh, bn=bn):
    beta = 0
    for k in np.arange(7):
        if x == "m":
            beta += bm[k] * sigma(vBias[k], V, -1)
        if x == "h":
            beta += bh[k] * sigma(vBias[k], V, 1)
        if x == "n":
            beta += bn[k] * sigma(vBias[k], V, -1)
    return beta

# %% [markdown]
# Prepare injected current

# %%
#Used to interpolate time points that are undefined in Idat
fIdat = interpolate.interp1d(np.arange(0,len(Idat)), Idat) 

sampling_rate = 5e3
def I_inj(t, scale=I_inj_scale):
    if t[0] * sampling_rate <= len(Idat):
        return fIdat(t * sampling_rate) * scale
    else:
        return 0

# %% [markdown]
# Define model

# %%
def neuron(t, y, k):
    #v, m, h, n = y
    v = y[:,0]
    m = y[:,1]
    h = y[:,2]
    n = y[:,3]
    # g = (2.62e-8, 5.25e-9, 4.9e-10)
    # E_rev = (1.109, 0.923, 0.9304)
    g = (k[0], k[1], k[2])
    E_rev = (k[3], k[4], k[5])
    
    I_na = g[0] * m**3 * h * (v - E_rev[0])
    I_k = g[1] * n**4 * (v - E_rev[1])
    I_l = g[2] * (v - E_rev[2])

    dvdt = (I_inj(t) - I_na - I_l - I_k) / C_m
    dmdt = alpha_spline(v, "m") * (1 - m) - beta_spline(v, "m") * m
    dhdt = alpha_spline(v, "h") * (1 - h) - beta_spline(v, "h") * h
    dndt = alpha_spline(v, "n") * (1 - n) - beta_spline(v, "n") * n
    dydt = np.transpose(np.array([dvdt, dmdt, dhdt, dndt]))
    
    return dydt

# %%
def nakl(t, y, P):
    """
    Neuron Model
    
    Paul's example has P as Pstim, which includes the stimulating current. Not sure if that is more efficient
    """
    v, m, h, n = (y[:,0], y[:,1], y[:,2], y[:,3])
    # Load parameters
    g = (P[0], P[1], P[2])
    E_rev = (P[3], P[4], P[5])
    vBias = (P[6:13])
    
    am = (P[13:20])
    bm = (P[20:27])
    ah = (P[27:34])
    bh = (P[34:41])
    an = (P[41:48])
    bn = (P[48:55])
    
    I_na = g[0] * m**3 * h * (v - E_rev[0])
    I_k = g[1] * n**4 * (v - E_rev[1])
    I_l = g[2] * (v - E_rev[2])

    dydt = np.zeros_like(y)

    dydt[:,0] = (I_inj(t) - I_na - I_l - I_k) / C_m
    dydt[:,1] = alpha_spline(v, "m", vBias) * (1 - m) - beta_spline(v, "m", vBias) * m
    dydt[:,2] = alpha_spline(v, "h", vBias) * (1 - h) - beta_spline(v, "h", vBias) * h
    dydt[:,3] = alpha_spline(v, "n", vBias) * (1 - n) - beta_spline(v, "n", vBias) * n
    
    return dydt

# %% [markdown]
# #### Action/annealing (hyper)parameters

# %%
# Model system dimension
D = 4

# Measured variable indices
# (-, t) (0, v) (1, m) (2, h) (3, n) (4, I)
Lidx = [0, 1, 2, 3]

# RM, RF0
RM = 1.0 / (0.5**2)
RF0 = 4.0e-6

# alpha, and beta ladder
alpha = 1.3
beta_array = np.linspace(0, 401, 401)
#beta_array = np.linspace(0, 80, 81)

g0 = RF0/RM
gammas_all = g0 * alpha**beta_array

# %% [markdown]
# #### Load observed data

# %%
data = np.load(os.getcwd() + "/ode_data.npy")
times_data = data[:, 0]
dt_data = times_data[1] - times_data[0]
N_data = len(times_data)

#extracting observed data here
data = data[:, 1:]
data = data[:, Lidx]

# %% [markdown]
# #### View observed data

# %%
fig, ax = plt.subplots(5,1, sharex=True)
fig.set_tight_layout(True)

ax[0].plot(times_data, data[:,0])
ax[0].set_ylabel('v')

ax[1].plot(times_data, data[:,1])
ax[1].set_ylabel('m')

ax[2].plot(times_data, data[:,2])
ax[2].set_ylabel('h')

ax[3].plot(times_data, data[:,3])
ax[3].set_ylabel('n')

ax[4].plot(times_data, I_inj(times_data))
ax[4].set_ylabel('I$_{inj}$')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Set $\Delta t_f$ based on $\Delta t$.

# %%
# model state discretization
freq_mod = 1.0  # how often to put down a state variable
dt_model = dt_data / freq_mod
if freq_mod == 1.0:
    N_model = N_data
else:
    N_model = int(N_data * freq_mod) - 1

# %% [markdown]
# #### Initial path/parameter guesses
# Later in the notebook, we'll have the option of setting the initial guesses for the observed variables equal to the observations themselves.

# %%
# State variables
# This should be an array with N_f elements, where element n_f is a D-dimensional 
# vector. In other words, this is an array of state vectors at all "model times".
X0 = (20.0*np.random.rand(N_model * D) - 10.0).reshape((N_model, D))

n_params = 6
#n_params = 55
# Parameters
Pidx = np.arange(0,n_params)

# %%
# Setting ranges for initial guesses
# r controls the size of the search space of the parameters
r = 0.1
Pg = []

# In case we want to estimate a subset of the full parameter set
param_counter = 0

for grp, params in enumerate(model_params):
    for p in params:
        param_counter += 1
        Pg.append([p * (1 - r), p * (1 + r)])
    if param_counter == n_params:
        break

# %%
# Compiling initial guesses
Pinit = np.zeros(len(Pidx))

# seed it!
np.random.seed(1)

# Initial guesses
for i, b in enumerate(Pg):
    r = b[1] - b[0]
    Pinit[i] = r*np.random.rand() + b[0]

# cast it as a numpy array
Pinit = np.array(Pinit)

# %%
print(Pinit)
# Out:
# [ 25.8557347    5.49012492   0.44368991   1.06595838   0.85789914
#    0.85457771]

# %%
print(Pinit)
# Out:
# [ 25.8557347    5.49012492   0.44368991   1.06595838   0.85789914
#    0.85457771]

# %% [markdown]
# #### Use VA to estimate states and parameters
# First we need to initialize an Annealer object, which stores information about the model, data, annealing hyperparameters, and the action.  It also executes the VA algorithm, then is used to save the state and parameter estimates to file.

# %%
# Initialize Annealer
anneal1 = va_ode.Annealer()

# Set the model
if n_params == 6:
    anneal1.set_model(neuron, D)
else:
    anneal1.set_model(nakl, D)

# Load the data into the Annealer object
anneal1.set_data(data, t=times_data)

# %% [markdown]
# Run VA

# %%
# First set some options for the optimization.
# Bounds [v], [m], [h], [n]
bounds = [[0 * V_scale, 1.5 * V_scale], [0.0, 1.0], [0.0, 1.0], [0.0, 1.0]]
for i in xrange(len(Pidx)):
    bounds.append(Pg[i])
    
    
# The full list of options can be found in the scipy.optimization package documentation.
BFGS_options = {'gtol':1.0e-8, 'ftol':1.0e-8, 'maxfun':1000000, 'maxiter':1000000}

tstart = time.time()  # time how long VA takes

# Annealer.anneal() executes VA for all beta values (defined above)
# Note the init_to_data option: this initializes the measured variables to the data.
anneal1.anneal(X0, Pinit, alpha, beta_array, RM, RF0, Lidx, Pidx, dt_model=dt_model,
               init_to_data=True, disc='SimpsonHermite', method='L-BFGS-B',
               opt_args=BFGS_options, bounds=bounds, adolcID=0)

print("\nADOL-C annealing completed in %f s."%(time.time() - tstart))
# Out:
# ------------------------------
# Step 1 of 401
# beta = 0, RF = 4.00000000e-06
#
# Taping action evaluation...
# Done!
# Time = 4.14286208153 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.83081793785 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  9.16021874e-10]
#
# ------------------------------
# Step 2 of 401
# beta = 1, RF = 5.20000000e-06
#
# Taping action evaluation...
# Done!
# Time = 4.74076700211 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.77256202698 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.19082726e-09]
#
# ------------------------------
# Step 3 of 401
# beta = 2, RF = 6.76000000e-06
#
# Taping action evaluation...
# Done!
# Time = 5.99603199959 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.50920295715 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.54807345e-09]
#
# ------------------------------
# Step 4 of 401
# beta = 3, RF = 8.78800000e-06
#
# Taping action evaluation...
# Done!
# Time = 4.70234417915 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.59565615654 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  2.01249213e-09]
#
# ------------------------------
# Step 5 of 401
# beta = 4, RF = 1.14244000e-05
#
# Taping action evaluation...
# Done!
# Time = 4.47843885422 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.33396100998 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  2.61623411e-09]
#
# ------------------------------
# Step 6 of 401
# beta = 5, RF = 1.48517200e-05
#
# Taping action evaluation...
# Done!
# Time = 4.25099611282 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.57036590576 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  3.40109476e-09]
#
# ------------------------------
# Step 7 of 401
# beta = 6, RF = 1.93072360e-05
#
# Taping action evaluation...
# Done!
# Time = 4.32986211777 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.57103300095 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  4.42140699e-09]
#
# ------------------------------
# Step 8 of 401
# beta = 7, RF = 2.50994068e-05
#
# Taping action evaluation...
# Done!
# Time = 4.11420893669 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.02912211418 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  5.74780172e-09]
#
# ------------------------------
# Step 9 of 401
# beta = 8, RF = 3.26292288e-05
#
# Taping action evaluation...
# Done!
# Time = 4.26043391228 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.56240510941 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  7.47209600e-09]
#
# ------------------------------
# Step 10 of 401
# beta = 9, RF = 4.24179975e-05
#
# Taping action evaluation...
# Done!
# Time = 4.30585002899 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.9901881218 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  9.71364665e-09]
#
# ------------------------------
# Step 11 of 401
# beta = 10, RF = 5.51433967e-05
#
# Taping action evaluation...
# Done!
# Time = 4.12354588509 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.51707220078 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.26276086e-08]
#
# ------------------------------
# Step 12 of 401
# beta = 11, RF = 7.16864158e-05
#
# Taping action evaluation...
# Done!
# Time = 4.22356009483 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.90170907974 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.64156680e-08]
#
# ------------------------------
# Step 13 of 401
# beta = 12, RF = 9.31923405e-05
#
# Taping action evaluation...
# Done!
# Time = 4.13846302032 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.98881697655 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  2.13399912e-08]
#
# ------------------------------
# Step 14 of 401
# beta = 13, RF = 1.21150043e-04
#
# Taping action evaluation...
# Done!
# Time = 4.23346590996 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.59493279457 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  2.77413511e-08]
#
# ------------------------------
# Step 15 of 401
# beta = 14, RF = 1.57495055e-04
#
# Taping action evaluation...
# Done!
# Time = 4.42255091667 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.55835700035 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  3.60626793e-08]
#
# ------------------------------
# Step 16 of 401
# beta = 15, RF = 2.04743572e-04
#
# Taping action evaluation...
# Done!
# Time = 4.28663611412 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.51661586761 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  4.68796628e-08]
#
# ------------------------------
# Step 17 of 401
# beta = 16, RF = 2.66166644e-04
#
# Taping action evaluation...
# Done!
# Time = 4.29334115982 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.93020796776 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  6.09404855e-08]
#
# ------------------------------
# Step 18 of 401
# beta = 17, RF = 3.46016637e-04
#
# Taping action evaluation...
# Done!
# Time = 4.30071902275 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.69229912758 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  7.92174328e-08]
#
# ------------------------------
# Step 19 of 401
# beta = 18, RF = 4.49821628e-04
#
# Taping action evaluation...
# Done!
# Time = 4.38851118088 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.9892911911 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.02973879e-07]
#
# ------------------------------
# Step 20 of 401
# beta = 19, RF = 5.84768116e-04
#
# Taping action evaluation...
# Done!
# Time = 5.32972598076 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.98466420174 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.33851199e-07]
#
# ------------------------------
# Step 21 of 401
# beta = 20, RF = 7.60198551e-04
#
# Taping action evaluation...
# Done!
# Time = 4.35613107681 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.72264385223 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.73981478e-07]
#
# ------------------------------
# Step 22 of 401
# beta = 21, RF = 9.88258116e-04
#
# Taping action evaluation...
# Done!
# Time = 4.3572781086 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.52960205078 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  2.26133545e-07]
#
# ------------------------------
# Step 23 of 401
# beta = 22, RF = 1.28473555e-03
#
# Taping action evaluation...
# Done!
# Time = 4.55841207504 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.60874295235 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  2.93902013e-07]
#
# ------------------------------
# Step 24 of 401
# beta = 23, RF = 1.67015622e-03
#
# Taping action evaluation...
# Done!
# Time = 4.30212497711 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.62089395523 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  3.81951668e-07]
#
# ------------------------------
# Step 25 of 401
# beta = 24, RF = 2.17120308e-03
#
# Taping action evaluation...
# Done!
# Time = 4.34323716164 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.57641601562 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  4.96332866e-07]
#
# ------------------------------
# Step 26 of 401
# beta = 25, RF = 2.82256401e-03
#
# Taping action evaluation...
# Done!
# Time = 4.65202999115 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.57987809181 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  6.44887679e-07]
#
# ------------------------------
# Step 27 of 401
# beta = 26, RF = 3.66933321e-03
#
# Taping action evaluation...
# Done!
# Time = 4.46803498268 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.74738407135 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  8.37771346e-07]
#
# ------------------------------
# Step 28 of 401
# beta = 27, RF = 4.77013317e-03
#
# Taping action evaluation...
# Done!
# Time = 4.29237484932 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.34174609184 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.08811917e-06]
#
# ------------------------------
# Step 29 of 401
# beta = 28, RF = 6.20117312e-03
#
# Taping action evaluation...
# Done!
# Time = 4.38413691521 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.56861591339 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.41289775e-06]
#
# ------------------------------
# Step 30 of 401
# beta = 29, RF = 8.06152506e-03
#
# Taping action evaluation...
# Done!
# Time = 4.37791585922 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.65255093575 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.83398050e-06]
#
# ------------------------------
# Step 31 of 401
# beta = 30, RF = 1.04799826e-02
#
# Taping action evaluation...
# Done!
# Time = 4.3003821373 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.51382899284 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  2.37947664e-06]
#
# ------------------------------
# Step 32 of 401
# beta = 31, RF = 1.36239773e-02
#
# Taping action evaluation...
# Done!
# Time = 4.35523509979 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.57510495186 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  3.08540470e-06]
#
# ------------------------------
# Step 33 of 401
# beta = 32, RF = 1.77111706e-02
#
# Taping action evaluation...
# Done!
# Time = 4.42495107651 s
#
# Beginning optimization...
# Optimization complete!
# Time = 4.334182024 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 12
# Obj. function value = [  3.25976750e-07]
#
# ------------------------------
# Step 34 of 401
# beta = 33, RF = 2.30245217e-02
#
# Taping action evaluation...
# Done!
# Time = 4.30504393578 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.06481695175 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  3.78640894e-07]
#
# ------------------------------
# Step 35 of 401
# beta = 34, RF = 2.99318782e-02
#
# Taping action evaluation...
# Done!
# Time = 4.32142496109 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.55840802193 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  4.46917528e-07]
#
# ------------------------------
# Step 36 of 401
# beta = 35, RF = 3.89114417e-02
#
# Taping action evaluation...
# Done!
# Time = 4.26568889618 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.57397913933 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  5.35327339e-07]
#
# ------------------------------
# Step 37 of 401
# beta = 36, RF = 5.05848742e-02
#
# Taping action evaluation...
# Done!
# Time = 4.386095047 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.56873083115 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  6.49645765e-07]
#
# ------------------------------
# Step 38 of 401
# beta = 37, RF = 6.57603365e-02
#
# Taping action evaluation...
# Done!
# Time = 4.36084508896 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.99841880798 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  7.97224654e-07]
#
# ------------------------------
# Step 39 of 401
# beta = 38, RF = 8.54884374e-02
#
# Taping action evaluation...
# Done!
# Time = 4.59418487549 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.98460698128 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  9.87387466e-07]
#
# ------------------------------
# Step 40 of 401
# beta = 39, RF = 1.11134969e-01
#
# Taping action evaluation...
# Done!
# Time = 4.52918100357 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.57893800735 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.23191509e-06]
#
# ------------------------------
# Step 41 of 401
# beta = 40, RF = 1.44475459e-01
#
# Taping action evaluation...
# Done!
# Time = 4.28497695923 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3.29893112183 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 8
# Obj. function value = [  8.15586256e-07]
#
# ------------------------------
# Step 42 of 401
# beta = 41, RF = 1.87818097e-01
#
# Taping action evaluation...
# Done!
# Time = 4.20241713524 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.08992004395 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  9.22115076e-07]
#
# ------------------------------
# Step 43 of 401
# beta = 42, RF = 2.44163526e-01
#
# Taping action evaluation...
# Done!
# Time = 4.23530817032 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.94794893265 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.06018282e-06]
#
# ------------------------------
# Step 44 of 401
# beta = 43, RF = 3.17412584e-01
#
# Taping action evaluation...
# Done!
# Time = 4.55637693405 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.69907212257 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.23884363e-06]
#
# ------------------------------
# Step 45 of 401
# beta = 44, RF = 4.12636359e-01
#
# Taping action evaluation...
# Done!
# Time = 4.28632307053 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.61219096184 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.46961237e-06]
#
# ------------------------------
# Step 46 of 401
# beta = 45, RF = 5.36427267e-01
#
# Taping action evaluation...
# Done!
# Time = 4.33221721649 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.56449198723 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.76705693e-06]
#
# ------------------------------
# Step 47 of 401
# beta = 46, RF = 6.97355447e-01
#
# Taping action evaluation...
# Done!
# Time = 4.72661018372 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.97850584984 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  2.14949246e-06]
#
# ------------------------------
# Step 48 of 401
# beta = 47, RF = 9.06562081e-01
#
# Taping action evaluation...
# Done!
# Time = 4.35492801666 s
#
# Beginning optimization...
# Optimization complete!
# Time = 9.36099410057 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 30
# Obj. function value = [  1.37600521e-06]
#
# ------------------------------
# Step 49 of 401
# beta = 48, RF = 1.17853071e+00
#
# Taping action evaluation...
# Done!
# Time = 4.19734501839 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.18364906311 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 2
# Obj. function value = [  1.53737844e-06]
#
# ------------------------------
# Step 50 of 401
# beta = 49, RF = 1.53208992e+00
#
# Taping action evaluation...
# Done!
# Time = 4.39215302467 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.59444689751 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.76553430e-06]
#
# ------------------------------
# Step 51 of 401
# beta = 50, RF = 1.99171689e+00
#
# Taping action evaluation...
# Done!
# Time = 4.3892261982 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.63928103447 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  2.06083152e-06]
#
# ------------------------------
# Step 52 of 401
# beta = 51, RF = 2.58923196e+00
#
# Taping action evaluation...
# Done!
# Time = 4.74015808105 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.97284698486 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  2.44255733e-06]
#
# ------------------------------
# Step 53 of 401
# beta = 52, RF = 3.36600155e+00
#
# Taping action evaluation...
# Done!
# Time = 5.35412192345 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.99911594391 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  2.93565240e-06]
#
# ------------------------------
# Step 54 of 401
# beta = 53, RF = 4.37580201e+00
#
# Taping action evaluation...
# Done!
# Time = 4.34751391411 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.41155099869 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 5
# Obj. function value = [  3.46014180e-06]
#
# ------------------------------
# Step 55 of 401
# beta = 54, RF = 5.68854262e+00
#
# Taping action evaluation...
# Done!
# Time = 4.29050207138 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.59404301643 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  4.25235119e-06]
#
# ------------------------------
# Step 56 of 401
# beta = 55, RF = 7.39510540e+00
#
# Taping action evaluation...
# Done!
# Time = 4.17887091637 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.21289300919 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  5.28441009e-06]
#
# ------------------------------
# Step 57 of 401
# beta = 56, RF = 9.61363702e+00
#
# Taping action evaluation...
# Done!
# Time = 4.37314105034 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.48810100555 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  6.62499569e-06]
#
# ------------------------------
# Step 58 of 401
# beta = 57, RF = 1.24977281e+01
#
# Taping action evaluation...
# Done!
# Time = 4.20438599586 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.74946093559 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  8.36635771e-06]
#
# ------------------------------
# Step 59 of 401
# beta = 58, RF = 1.62470466e+01
#
# Taping action evaluation...
# Done!
# Time = 4.30596089363 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.93829298019 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.06281362e-05]
#
# ------------------------------
# Step 60 of 401
# beta = 59, RF = 2.11211605e+01
#
# Taping action evaluation...
# Done!
# Time = 4.33854389191 s
#
# Beginning optimization...
# Optimization complete!
# Time = 18.3540458679 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 68
# Obj. function value = [  7.30608662e-06]
#
# ------------------------------
# Step 61 of 401
# beta = 60, RF = 2.74575087e+01
#
# Taping action evaluation...
# Done!
# Time = 4.31562399864 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.825289011 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  8.88881591e-06]
#
# ------------------------------
# Step 62 of 401
# beta = 61, RF = 3.56947613e+01
#
# Taping action evaluation...
# Done!
# Time = 5.39462900162 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.30126309395 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.09463222e-05]
#
# ------------------------------
# Step 63 of 401
# beta = 62, RF = 4.64031897e+01
#
# Taping action evaluation...
# Done!
# Time = 4.67899990082 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.6201710701 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.36203384e-05]
#
# ------------------------------
# Step 64 of 401
# beta = 63, RF = 6.03241466e+01
#
# Taping action evaluation...
# Done!
# Time = 4.51734900475 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.18930196762 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.70953230e-05]
#
# ------------------------------
# Step 65 of 401
# beta = 64, RF = 7.84213906e+01
#
# Taping action evaluation...
# Done!
# Time = 4.39327597618 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.80856394768 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  2.16110453e-05]
#
# ------------------------------
# Step 66 of 401
# beta = 65, RF = 1.01947808e+02
#
# Taping action evaluation...
# Done!
# Time = 4.25042486191 s
#
# Beginning optimization...
# Optimization complete!
# Time = 24.2406539917 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 98
# Obj. function value = [  1.44197356e-05]
#
# ------------------------------
# Step 67 of 401
# beta = 66, RF = 1.32532150e+02
#
# Taping action evaluation...
# Done!
# Time = 4.2907910347 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.4038169384 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 2
# Obj. function value = [  1.71097512e-05]
#
# ------------------------------
# Step 68 of 401
# beta = 67, RF = 1.72291795e+02
#
# Taping action evaluation...
# Done!
# Time = 4.17449784279 s
#
# Beginning optimization...
# Optimization complete!
# Time = 38.6723270416 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 132
# Obj. function value = [  1.54111093e-05]
#
# ------------------------------
# Step 69 of 401
# beta = 68, RF = 2.23979334e+02
#
# Taping action evaluation...
# Done!
# Time = 6.25819897652 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3.93161082268 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 2
# Obj. function value = [  1.80827028e-05]
#
# ------------------------------
# Step 70 of 401
# beta = 69, RF = 2.91173134e+02
#
# Taping action evaluation...
# Done!
# Time = 5.8456261158 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3.56983089447 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 3
# Obj. function value = [  2.15524939e-05]
#
# ------------------------------
# Step 71 of 401
# beta = 70, RF = 3.78525074e+02
#
# Taping action evaluation...
# Done!
# Time = 5.31231403351 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3.11239385605 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 3
# Obj. function value = [  2.60801770e-05]
#
# ------------------------------
# Step 72 of 401
# beta = 71, RF = 4.92082596e+02
#
# Taping action evaluation...
# Done!
# Time = 5.27908396721 s
#
# Beginning optimization...
# Optimization complete!
# Time = 62.5622398853 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 232
# Obj. function value = [  1.95501915e-05]
#
# ------------------------------
# Step 73 of 401
# beta = 72, RF = 6.39707375e+02
#
# Taping action evaluation...
# Done!
# Time = 5.22696304321 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.89132285118 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  2.23176688e-05]
#
# ------------------------------
# Step 74 of 401
# beta = 73, RF = 8.31619587e+02
#
# Taping action evaluation...
# Done!
# Time = 4.91980910301 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.95276212692 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  2.59154757e-05]
#
# ------------------------------
# Step 75 of 401
# beta = 74, RF = 1.08110546e+03
#
# Taping action evaluation...
# Done!
# Time = 5.27251887321 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.6309299469 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  3.05921104e-05]
#
# ------------------------------
# Step 76 of 401
# beta = 75, RF = 1.40543710e+03
#
# Taping action evaluation...
# Done!
# Time = 4.83733201027 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.8469350338 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  3.66706426e-05]
#
# ------------------------------
# Step 77 of 401
# beta = 76, RF = 1.82706823e+03
#
# Taping action evaluation...
# Done!
# Time = 4.58561682701 s
#
# Beginning optimization...
# Optimization complete!
# Time = 12.9336059093 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 42
# Obj. function value = [  4.26681972e-05]
#
# ------------------------------
# Step 78 of 401
# beta = 77, RF = 2.37518870e+03
#
# Taping action evaluation...
# Done!
# Time = 4.98191189766 s
#
# Beginning optimization...
# Optimization complete!
# Time = 78.1754498482 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 318
# Obj. function value = [  2.99528513e-05]
#
# ------------------------------
# Step 79 of 401
# beta = 78, RF = 3.08774531e+03
#
# Taping action evaluation...
# Done!
# Time = 4.73454904556 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.20338010788 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 2
# Obj. function value = [  3.47890809e-05]
#
# ------------------------------
# Step 80 of 401
# beta = 79, RF = 4.01406891e+03
#
# Taping action evaluation...
# Done!
# Time = 4.83093595505 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.84879398346 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  4.10850856e-05]
#
# ------------------------------
# Step 81 of 401
# beta = 80, RF = 5.21828958e+03
#
# Taping action evaluation...
# Done!
# Time = 4.57858991623 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.39484786987 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  4.92701607e-05]
#
# ------------------------------
# Step 82 of 401
# beta = 81, RF = 6.78377645e+03
#
# Taping action evaluation...
# Done!
# Time = 4.54172492027 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.21487498283 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  5.99104134e-05]
#
# ------------------------------
# Step 83 of 401
# beta = 82, RF = 8.81890939e+03
#
# Taping action evaluation...
# Done!
# Time = 4.59442806244 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.47751116753 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  7.37419773e-05]
#
# ------------------------------
# Step 84 of 401
# beta = 83, RF = 1.14645822e+04
#
# Taping action evaluation...
# Done!
# Time = 4.66637802124 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.71471381187 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  9.17218374e-05]
#
# ------------------------------
# Step 85 of 401
# beta = 84, RF = 1.49039569e+04
#
# Taping action evaluation...
# Done!
# Time = 4.881513834 s
#
# Beginning optimization...
# Optimization complete!
# Time = 135.613914013 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 557
# Obj. function value = [  6.51356260e-05]
#
# ------------------------------
# Step 86 of 401
# beta = 85, RF = 1.93751439e+04
#
# Taping action evaluation...
# Done!
# Time = 5.147990942 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.47546219826 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 2
# Obj. function value = [  7.96379363e-05]
#
# ------------------------------
# Step 87 of 401
# beta = 86, RF = 2.51876871e+04
#
# Taping action evaluation...
# Done!
# Time = 4.70765900612 s
#
# Beginning optimization...
# Optimization complete!
# Time = 10.0019929409 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 36
# Obj. function value = [  9.76184326e-05]
#
# ------------------------------
# Step 88 of 401
# beta = 87, RF = 3.27439932e+04
#
# Taping action evaluation...
# Done!
# Time = 5.40990304947 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.85210299492 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 2
# Obj. function value = [ 0.00012189]
#
# ------------------------------
# Step 89 of 401
# beta = 88, RF = 4.25671912e+04
#
# Taping action evaluation...
# Done!
# Time = 4.77989983559 s
#
# Beginning optimization...
# Optimization complete!
# Time = 274.995795965 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1112
# Obj. function value = [  7.90254432e-05]
#
# ------------------------------
# Step 90 of 401
# beta = 89, RF = 5.53373486e+04
#
# Taping action evaluation...
# Done!
# Time = 4.93557190895 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3.06554889679 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 2
# Obj. function value = [  9.67304475e-05]
#
# ------------------------------
# Step 91 of 401
# beta = 90, RF = 7.19385532e+04
#
# Taping action evaluation...
# Done!
# Time = 4.93301510811 s
#
# Beginning optimization...
# Optimization complete!
# Time = 7.86435008049 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 23
# Obj. function value = [ 0.00011929]
#
# ------------------------------
# Step 92 of 401
# beta = 91, RF = 9.35201191e+04
#
# Taping action evaluation...
# Done!
# Time = 4.85334920883 s
#
# Beginning optimization...
# Optimization complete!
# Time = 4.61012411118 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 5
# Obj. function value = [ 0.00014901]
#
# ------------------------------
# Step 93 of 401
# beta = 92, RF = 1.21576155e+05
#
# Taping action evaluation...
# Done!
# Time = 4.70704197884 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3.37644195557 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [ 0.00018775]
#
# ------------------------------
# Step 94 of 401
# beta = 93, RF = 1.58049001e+05
#
# Taping action evaluation...
# Done!
# Time = 4.77397012711 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.25567889214 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [ 0.00023812]
#
# ------------------------------
# Step 95 of 401
# beta = 94, RF = 2.05463702e+05
#
# Taping action evaluation...
# Done!
# Time = 4.65633106232 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.31283116341 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [ 0.00030359]
#
# ------------------------------
# Step 96 of 401
# beta = 95, RF = 2.67102812e+05
#
# Taping action evaluation...
# Done!
# Time = 4.71042585373 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.36246204376 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [ 0.0003887]
#
# ------------------------------
# Step 97 of 401
# beta = 96, RF = 3.47233656e+05
#
# Taping action evaluation...
# Done!
# Time = 4.74326896667 s
#
# Beginning optimization...
# Optimization complete!
# Time = 330.486393929 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1432
# Obj. function value = [ 0.00030868]
#
# ------------------------------
# Step 98 of 401
# beta = 97, RF = 4.51403753e+05
#
# Taping action evaluation...
# Done!
# Time = 4.70130085945 s
#
# Beginning optimization...
# Optimization complete!
# Time = 16.933191061 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 66
# Obj. function value = [ 0.00039271]
#
# ------------------------------
# Step 99 of 401
# beta = 98, RF = 5.86824878e+05
#
# Taping action evaluation...
# Done!
# Time = 4.630204916 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3.01739001274 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 2
# Obj. function value = [ 0.00050362]
#
# ------------------------------
# Step 100 of 401
# beta = 99, RF = 7.62872342e+05
#
# Taping action evaluation...
# Done!
# Time = 4.52300095558 s
#
# Beginning optimization...
# Optimization complete!
# Time = 6.81660103798 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 22
# Obj. function value = [ 0.00064741]
#
# ------------------------------
# Step 101 of 401
# beta = 100, RF = 9.91734044e+05
#
# Taping action evaluation...
# Done!
# Time = 5.00674891472 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3.38108897209 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 2
# Obj. function value = [ 0.00083474]
#
# ------------------------------
# Step 102 of 401
# beta = 101, RF = 1.28925426e+06
#
# Taping action evaluation...
# Done!
# Time = 4.5065112114 s
#
# Beginning optimization...
# Optimization complete!
# Time = 6.63053798676 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 10
# Obj. function value = [ 0.00107813]
#
# ------------------------------
# Step 103 of 401
# beta = 102, RF = 1.67603054e+06
#
# Taping action evaluation...
# Done!
# Time = 6.06687903404 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3.62901711464 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 2
# Obj. function value = [ 0.00139469]
#
# ------------------------------
# Step 104 of 401
# beta = 103, RF = 2.17883970e+06
#
# Taping action evaluation...
# Done!
# Time = 6.73101091385 s
#
# Beginning optimization...
# Optimization complete!
# Time = 4.0148460865 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 3
# Obj. function value = [ 0.0018062]
#
# ------------------------------
# Step 105 of 401
# beta = 104, RF = 2.83249160e+06
#
# Taping action evaluation...
# Done!
# Time = 6.15241408348 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3.22248196602 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [ 0.0023412]
#
# ------------------------------
# Step 106 of 401
# beta = 105, RF = 3.68223909e+06
#
# Taping action evaluation...
# Done!
# Time = 6.48184680939 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3.18306708336 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [ 0.0030367]
#
# ------------------------------
# Step 107 of 401
# beta = 106, RF = 4.78691081e+06
#
# Taping action evaluation...
# Done!
# Time = 5.76834607124 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3.28402686119 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [ 0.00394085]
#
# ------------------------------
# Step 108 of 401
# beta = 107, RF = 6.22298405e+06
#
# Taping action evaluation...
# Done!
# Time = 5.87281703949 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3.20153093338 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [ 0.00511624]
#
# ------------------------------
# Step 109 of 401
# beta = 108, RF = 8.08987927e+06
#
# Taping action evaluation...
# Done!
# Time = 6.19834303856 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3803.52784014 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 13095
# Obj. function value = [ 0.00243714]
#
# ------------------------------
# Step 110 of 401
# beta = 109, RF = 1.05168431e+07
#
# Taping action evaluation...
# Done!
# Time = 5.32134413719 s
#
# Beginning optimization...
# Optimization complete!
# Time = 4.49909710884 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 10
# Obj. function value = [ 0.00315657]
#
# ------------------------------
# Step 111 of 401
# beta = 110, RF = 1.36718960e+07
#
# Taping action evaluation...
# Done!
# Time = 5.03260087967 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.12360692024 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 2
# Obj. function value = [ 0.00409208]
#
# ------------------------------
# Step 112 of 401
# beta = 111, RF = 1.77734648e+07
#
# Taping action evaluation...
# Done!
# Time = 5.04330301285 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3.99897098541 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 6
# Obj. function value = [ 0.00530819]
#
# ------------------------------
# Step 113 of 401
# beta = 112, RF = 2.31055042e+07
#
# Taping action evaluation...
# Done!
# Time = 4.97768616676 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.88903284073 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 3
# Obj. function value = [ 0.00688918]
#
# ------------------------------
# Step 114 of 401
# beta = 113, RF = 3.00371554e+07
#
# Taping action evaluation...
# Done!
# Time = 4.80841588974 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3.40754008293 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 4
# Obj. function value = [ 0.00894444]
#
# ------------------------------
# Step 115 of 401
# beta = 114, RF = 3.90483021e+07
#
# Taping action evaluation...
# Done!
# Time = 4.99133992195 s
#
# Beginning optimization...
# Optimization complete!
# Time = 14.419479847 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 51
# Obj. function value = [ 0.01161217]
#
# ------------------------------
# Step 116 of 401
# beta = 115, RF = 5.07627927e+07
#
# Taping action evaluation...
# Done!
# Time = 4.93148303032 s
#
# Beginning optimization...
# Optimization complete!
# Time = 16.8352320194 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 59
# Obj. function value = [ 0.01508174]
#
# ------------------------------
# Step 117 of 401
# beta = 116, RF = 6.59916305e+07
#
# Taping action evaluation...
# Done!
# Time = 5.04554390907 s
#
# Beginning optimization...
# Optimization complete!
# Time = 6286.72573304 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 27133
# Obj. function value = [ 0.00716053]
#
# ------------------------------
# Step 118 of 401
# beta = 117, RF = 8.57891197e+07
#
# Taping action evaluation...
# Done!
# Time = 4.62588882446 s
#
# Beginning optimization...
# Optimization complete!
# Time = 11.0194950104 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 37
# Obj. function value = [ 0.00928031]
#
# ------------------------------
# Step 119 of 401
# beta = 118, RF = 1.11525856e+08
#
# Taping action evaluation...
# Done!
# Time = 4.55093789101 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.66542983055 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 2
# Obj. function value = [ 0.01203719]
#
# ------------------------------
# Step 120 of 401
# beta = 119, RF = 1.44983612e+08
#
# Taping action evaluation...
# Done!
# Time = 4.49207615852 s
#
# Beginning optimization...
# Optimization complete!
# Time = 10.2415699959 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 33
# Obj. function value = [ 0.0156205]
#
# ------------------------------
# Step 121 of 401
# beta = 120, RF = 1.88478696e+08
#
# Taping action evaluation...
# Done!
# Time = 4.51722502708 s
#
# Beginning optimization...
# Optimization complete!
# Time = 3.41765093803 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 2
# Obj. function value = [ 0.02027944]
#
# ------------------------------
# Step 122 of 401
# beta = 121, RF = 2.45022305e+08
#
# Taping action evaluation...
# Done!
# Time = 4.51434206963 s
#
# Beginning optimization...
# Optimization complete!
# Time = 9.10972213745 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 27
# Obj. function value = [ 0.02633545]
#
# ------------------------------
# Step 123 of 401
# beta = 122, RF = 3.18528996e+08
#
# Taping action evaluation...
# Done!
# Time = 4.42675495148 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.63981699944 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 2
# Obj. function value = [ 0.03420888]
#
# ------------------------------
# Step 124 of 401
# beta = 123, RF = 4.14087695e+08
#
# Taping action evaluation...
# Done!
# Time = 4.55558609962 s
#
# Beginning optimization...
# Optimization complete!
# Time = 9228.72673917 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 39710
# Obj. function value = [ 0.0195865]
#
# ------------------------------
# Step 125 of 401
# beta = 124, RF = 5.38314003e+08
#
# Taping action evaluation...
# Done!
# Time = 4.07940793037 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.97881698608 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 3
# Obj. function value = [ 0.02541788]
#
# ------------------------------
# Step 126 of 401
# beta = 125, RF = 6.99808204e+08
#
# Taping action evaluation...
# Done!
# Time = 3.78043484688 s
#
# Beginning optimization...
# Optimization complete!
# Time = 14.319986105 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 58
# Obj. function value = [ 0.03299738]
#
# ------------------------------
# Step 127 of 401
# beta = 126, RF = 9.09750666e+08
#
# Taping action evaluation...
# Done!
# Time = 3.78935909271 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.4961810112 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 5
# Obj. function value = [ 0.04285205]
#
# ------------------------------
# Step 128 of 401
# beta = 127, RF = 1.18267587e+09
#
# Taping action evaluation...
# Done!
# Time = 3.82050919533 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.56670999527 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 2
# Obj. function value = [ 0.05566319]
#
# ------------------------------
# Step 129 of 401
# beta = 128, RF = 1.53747862e+09
#
# Taping action evaluation...
# Done!
# Time = 3.85411000252 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.01322889328 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [ 0.07231768]
#
# ------------------------------
# Step 130 of 401
# beta = 129, RF = 1.99872221e+09
#
# Taping action evaluation...
# Done!
# Time = 3.86525988579 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.02128100395 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [ 0.09396853]
#
# ------------------------------
# Step 131 of 401
# beta = 130, RF = 2.59833888e+09
#
# Taping action evaluation...
# Done!
# Time = 3.78359389305 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.90496897697 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [ 0.12211463]
#
# ------------------------------
# Step 132 of 401
# beta = 131, RF = 3.37784054e+09
#
# Taping action evaluation...
# Done!
# Time = 3.80541396141 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.50661492348 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 2
# Obj. function value = [ 0.15870454]
#
# ------------------------------
# Step 133 of 401
# beta = 132, RF = 4.39119270e+09
#
# Taping action evaluation...
# Done!
# Time = 3.8692522049 s
#
# Beginning optimization...
# Optimization complete!
# Time = 31507.0730722 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 127425
# Obj. function value = [ 0.1087084]
#
# ------------------------------
# Step 134 of 401
# beta = 133, RF = 5.70855051e+09
#
# Taping action evaluation...
# Done!
# Time = 4.20640206337 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.42369008064 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 5
# Obj. function value = [ 0.1412553]
#
# ------------------------------
# Step 135 of 401
# beta = 134, RF = 7.42111566e+09
#
# Taping action evaluation...
# Done!
# Time = 3.76949596405 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.07855081558 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 3
# Obj. function value = [ 0.18356636]
#
# ------------------------------
# Step 136 of 401
# beta = 135, RF = 9.64745036e+09
#
# Taping action evaluation...
# Done!
# Time = 3.78023505211 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.63508701324 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [ 0.23857077]
#
# ------------------------------
# Step 137 of 401
# beta = 136, RF = 1.25416855e+10
#
# Taping action evaluation...
# Done!
# Time = 3.69749903679 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.29236984253 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [ 0.3100765]
#
# ------------------------------
# Step 138 of 401
# beta = 137, RF = 1.63041911e+10
#
# Taping action evaluation...
# Done!
# Time = 4.36384797096 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.96805500984 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [ 0.40303394]
#
# ------------------------------
# Step 139 of 401
# beta = 138, RF = 2.11954484e+10
#
# Taping action evaluation...
# Done!
# Time = 4.15215396881 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.94402098656 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 2
# Obj. function value = [ 0.52387861]
#
# ------------------------------
# Step 140 of 401
# beta = 139, RF = 2.75540830e+10
#
# Taping action evaluation...
# Done!
# Time = 3.96780610085 s
#
# Beginning optimization...
# Optimization complete!
# Time = 73015.6902051 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 331705
# Obj. function value = [ 0.34815062]
#
# ------------------------------
# Step 141 of 401
# beta = 140, RF = 3.58203079e+10
#
# Taping action evaluation...
# Done!
# Time = 4.16666102409 s
#
# Beginning optimization...
# Optimization complete!
# Time = 12.9005720615 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 55
# Obj. function value = [ 0.45249643]
#
# ------------------------------
# Step 142 of 401
# beta = 141, RF = 4.65664002e+10
#
# ...
# Optimization complete!
# Time = 2.14184808731 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.09440709e+24]
#
# ------------------------------
# Step 356 of 401
# beta = 355, RF = 1.12706785e+35
#
# Taping action evaluation...
# Done!
# Time = 3.69103884697 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.52120685577 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.42272922e+24]
#
# ------------------------------
# Step 357 of 401
# beta = 356, RF = 1.46518820e+35
#
# Taping action evaluation...
# Done!
# Time = 3.83611917496 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.21950912476 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.84954798e+24]
#
# ------------------------------
# Step 358 of 401
# beta = 357, RF = 1.90474466e+35
#
# Taping action evaluation...
# Done!
# Time = 4.49986195564 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.58309102058 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  2.40441238e+24]
#
# ------------------------------
# Step 359 of 401
# beta = 358, RF = 2.47616806e+35
#
# Taping action evaluation...
# Done!
# Time = 3.81727910042 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.89442801476 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  3.12573609e+24]
#
# ------------------------------
# Step 360 of 401
# beta = 359, RF = 3.21901848e+35
#
# Taping action evaluation...
# Done!
# Time = 3.72267699242 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.15665197372 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  4.06345691e+24]
#
# ------------------------------
# Step 361 of 401
# beta = 360, RF = 4.18472402e+35
#
# Taping action evaluation...
# Done!
# Time = 3.65836596489 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.57031702995 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  5.28249398e+24]
#
# ------------------------------
# Step 362 of 401
# beta = 361, RF = 5.44014123e+35
#
# Taping action evaluation...
# Done!
# Time = 3.99903988838 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.90273714066 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  6.86724217e+24]
#
# ------------------------------
# Step 363 of 401
# beta = 362, RF = 7.07218359e+35
#
# Taping action evaluation...
# Done!
# Time = 3.74935889244 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.1858959198 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  8.92741481e+24]
#
# ------------------------------
# Step 364 of 401
# beta = 363, RF = 9.19383867e+35
#
# Taping action evaluation...
# Done!
# Time = 3.7219247818 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.24368095398 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.16056392e+25]
#
# ------------------------------
# Step 365 of 401
# beta = 364, RF = 1.19519903e+36
#
# Taping action evaluation...
# Done!
# Time = 3.68171310425 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.09647798538 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.50873310e+25]
#
# ------------------------------
# Step 366 of 401
# beta = 365, RF = 1.55375874e+36
#
# Taping action evaluation...
# Done!
# Time = 3.77606487274 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.20682191849 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.96135303e+25]
#
# ------------------------------
# Step 367 of 401
# beta = 366, RF = 2.01988636e+36
#
# Taping action evaluation...
# Done!
# Time = 4.00602507591 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.2496380806 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  2.54975894e+25]
#
# ------------------------------
# Step 368 of 401
# beta = 367, RF = 2.62585226e+36
#
# Taping action evaluation...
# Done!
# Time = 3.68151879311 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.15249800682 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  3.31468661e+25]
#
# ------------------------------
# Step 369 of 401
# beta = 368, RF = 3.41360794e+36
#
# Taping action evaluation...
# Done!
# Time = 3.68846678734 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.14677906036 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  4.30909260e+25]
#
# ------------------------------
# Step 370 of 401
# beta = 369, RF = 4.43769032e+36
#
# Taping action evaluation...
# Done!
# Time = 3.77520489693 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.1796298027 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  5.60182037e+25]
#
# ------------------------------
# Step 371 of 401
# beta = 370, RF = 5.76899742e+36
#
# Taping action evaluation...
# Done!
# Time = 3.78092694283 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.19361400604 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  7.28236648e+25]
#
# ------------------------------
# Step 372 of 401
# beta = 371, RF = 7.49969665e+36
#
# Taping action evaluation...
# Done!
# Time = 3.8273601532 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.22660899162 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  9.46707641e+25]
#
# ------------------------------
# Step 373 of 401
# beta = 372, RF = 9.74960564e+36
#
# Taping action evaluation...
# Done!
# Time = 3.63807415962 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.54738998413 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.23071993e+26]
#
# ------------------------------
# Step 374 of 401
# beta = 373, RF = 1.26744873e+37
#
# Taping action evaluation...
# Done!
# Time = 3.67553496361 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.20308303833 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.59993591e+26]
#
# ------------------------------
# Step 375 of 401
# beta = 374, RF = 1.64768335e+37
#
# Taping action evaluation...
# Done!
# Time = 3.76905894279 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.22534298897 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  2.07991668e+26]
#
# ------------------------------
# Step 376 of 401
# beta = 375, RF = 2.14198836e+37
#
# Taping action evaluation...
# Done!
# Time = 3.6838619709 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.25678300858 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  2.70389169e+26]
#
# ------------------------------
# Step 377 of 401
# beta = 376, RF = 2.78458487e+37
#
# Taping action evaluation...
# Done!
# Time = 3.69551301003 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.28510308266 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  3.51505919e+26]
#
# ------------------------------
# Step 378 of 401
# beta = 377, RF = 3.61996033e+37
#
# Taping action evaluation...
# Done!
# Time = 3.79219388962 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.25152206421 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  4.56957694e+26]
#
# ------------------------------
# Step 379 of 401
# beta = 378, RF = 4.70594843e+37
#
# Taping action evaluation...
# Done!
# Time = 3.74117398262 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.17904806137 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  5.94045002e+26]
#
# ------------------------------
# Step 380 of 401
# beta = 379, RF = 6.11773295e+37
#
# Taping action evaluation...
# Done!
# Time = 3.72557902336 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.1491420269 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  7.72258503e+26]
#
# ------------------------------
# Step 381 of 401
# beta = 380, RF = 7.95305284e+37
#
# Taping action evaluation...
# Done!
# Time = 3.68598794937 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.52910709381 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.00393605e+27]
#
# ------------------------------
# Step 382 of 401
# beta = 381, RF = 1.03389687e+38
#
# Taping action evaluation...
# Done!
# Time = 3.70588207245 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.23414516449 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.30511687e+27]
#
# ------------------------------
# Step 383 of 401
# beta = 382, RF = 1.34406593e+38
#
# Taping action evaluation...
# Done!
# Time = 3.71164011955 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.23299098015 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.69665193e+27]
#
# ------------------------------
# Step 384 of 401
# beta = 383, RF = 1.74728571e+38
#
# Taping action evaluation...
# Done!
# Time = 3.80707716942 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.16741991043 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  2.20564750e+27]
#
# ------------------------------
# Step 385 of 401
# beta = 384, RF = 2.27147142e+38
#
# Taping action evaluation...
# Done!
# Time = 3.74909901619 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.20227003098 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  2.86734175e+27]
#
# ------------------------------
# Step 386 of 401
# beta = 385, RF = 2.95291285e+38
#
# Taping action evaluation...
# Done!
# Time = 3.68452906609 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.23136496544 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  3.72754428e+27]
#
# ------------------------------
# Step 387 of 401
# beta = 386, RF = 3.83878670e+38
#
# Taping action evaluation...
# Done!
# Time = 3.76840615273 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.2275531292 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  4.84580755e+27]
#
# ------------------------------
# Step 388 of 401
# beta = 387, RF = 4.99042271e+38
#
# Taping action evaluation...
# Done!
# Time = 3.78345108032 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.14028096199 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  6.29954982e+27]
#
# ------------------------------
# Step 389 of 401
# beta = 388, RF = 6.48754953e+38
#
# Taping action evaluation...
# Done!
# Time = 3.68498516083 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.26198387146 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  8.18941476e+27]
#
# ------------------------------
# Step 390 of 401
# beta = 389, RF = 8.43381439e+38
#
# Taping action evaluation...
# Done!
# Time = 3.75091505051 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.22971606255 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.06462392e+28]
#
# ------------------------------
# Step 391 of 401
# beta = 390, RF = 1.09639587e+39
#
# Taping action evaluation...
# Done!
# Time = 3.63048505783 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.54930615425 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.38401109e+28]
#
# ------------------------------
# Step 392 of 401
# beta = 391, RF = 1.42531463e+39
#
# Taping action evaluation...
# Done!
# Time = 3.70493507385 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.1871650219 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.79921442e+28]
#
# ------------------------------
# Step 393 of 401
# beta = 392, RF = 1.85290902e+39
#
# Taping action evaluation...
# Done!
# Time = 3.75283503532 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.22031283379 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  2.33897874e+28]
#
# ------------------------------
# Step 394 of 401
# beta = 393, RF = 2.40878173e+39
#
# Taping action evaluation...
# Done!
# Time = 3.69647502899 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.2271361351 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  3.04067236e+28]
#
# ------------------------------
# Step 395 of 401
# beta = 394, RF = 3.13141624e+39
#
# Taping action evaluation...
# Done!
# Time = 3.75071597099 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.30182814598 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  3.95287407e+28]
#
# ------------------------------
# Step 396 of 401
# beta = 395, RF = 4.07084112e+39
#
# Taping action evaluation...
# Done!
# Time = 3.69901299477 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.17150497437 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  5.13873629e+28]
#
# ------------------------------
# Step 397 of 401
# beta = 396, RF = 5.29209345e+39
#
# Taping action evaluation...
# Done!
# Time = 3.71720504761 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.21363782883 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  6.68035717e+28]
#
# ------------------------------
# Step 398 of 401
# beta = 397, RF = 6.87972149e+39
#
# Taping action evaluation...
# Done!
# Time = 3.84032201767 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.23122787476 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  8.68446431e+28]
#
# ------------------------------
# Step 399 of 401
# beta = 398, RF = 8.94363794e+39
#
# Taping action evaluation...
# Done!
# Time = 3.77460813522 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.19613289833 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.12898036e+29]
#
# ------------------------------
# Step 400 of 401
# beta = 399, RF = 1.16267293e+40
#
# Taping action evaluation...
# Done!
# Time = 3.71330904961 s
#
# Beginning optimization...
# Optimization complete!
# Time = 2.21934294701 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  1.46767447e+29]
#
# ------------------------------
# Step 401 of 401
# beta = 401, RF = 1.96491725e+40
#
# Taping action evaluation...
# Done!
# Time = 4.39406490326 s
#
# Beginning optimization...
# Optimization complete!
# Time = 1.7972741127 s
# Exit flag = 0
# Exit message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Iterations = 1
# Obj. function value = [  2.48036985e+29]
#
#
# ADOL-C annealing completed in 127391.380250 s.

# %% [markdown]
# # Save action, constituent errors, and state/parameter estimates to file.

# %%
anneal1.save_paths("neurodyn/paths.npy") #state paths
anneal1.save_params("neurodyn/params.npy")
anneal1.save_action_errors("neurodyn/action_errors.npy")#saves action and constituent errors

# %% [markdown]
# ### Plot the results

# %% [markdown]
# #### One measured, one unmeasured state variable

# %%
# Load path estimates and action curves
allpaths = np.load("neurodyn/paths.npy")
aerr = np.load("neurodyn/action_errors.npy")
params = np.load("neurodyn/params.npy")
# Load the true solution
true_soln = np.load("/Users/alexanderjulianty/neurodyn/ode_data.npy")

# %%
np.around(params[(0,20,40,60,80),:].T, 5)
# Out:
# array([[ 25.85573,  25.85573,  25.85576,  25.85568,  25.85589],
#        [  5.49012,   5.49012,   5.48967,   5.48872,   5.48591],
#        [  0.44369,   0.44369,   0.44368,   0.45257,   0.48016],
#        [  1.06596,   1.06598,   1.10959,   1.10925,   1.10996],
#        [  0.8579 ,   0.8579 ,   0.87707,   0.91859,   0.92513],
#        [  0.85458,   0.85458,   0.93657,   0.93017,   0.93029]])

# %%
format(params[0,:][0],'f')
# Out:
# '25.855735'

# %%
model_params[0:2]
# Out:
# [array([ 26.29206731,   5.25841346,   0.49297626]),
#  array([ 1.10983398,  0.92311621,  0.93043848])]

# %%
def rmse(x,y, normalize=True): 
    """
    Computes the percent mse of two row vectors
    
    x: vector 1
    y: vector 2
    """
    x, y = (np.array(x), np.array(y))
    error = y - x
    if normalize == True:
        mask = x != 0
        error[:,mask] = np.divide(error[:,mask], x[mask])
    sq_error = np.square(error)
    mean_sq_error = sq_error.mean(axis=1)
    rmsq_error = np.sqrt(mean_sq_error)
    return rmsq_error

def param_error(model_params, params, breakdown=False):
    """
    Used to compute the RMSE of the two inputs.
    
    model_params: list or array of true model parameters
    params: list or array of parameters estimated using varanneal
    """
    #coerce params to np.arrays
    mp = np.array(model_params)
    
    #Thing messes up if you only give it one row, so here's a workaround
    try: 
        if params.shape[1] != 0:
            par = np.array(params)
    except IndexError: 
        par = np.array(params)[None,:]

    #0:3 are the conductances
    #3:6 are the reversal potentials
    #6:13 are the vBias values
    #13:20 are am[] values
    #20:27 are bm[] values
    #27:34 are ah[] values
    #34:41 are bh[] values
    #41:48 are an[] values
    #48:55 are bn[] values
    tot_rmse = []
    tot_rmse.append(rmse(mp[0], par[:,0:3]))
    tot_rmse.append(rmse(mp[1], par[:,3:6]))
    tot_rmse.append(rmse(mp[2], par[:,6:13]))
    tot_rmse.append(rmse(mp[3], par[:,13:20]))
    tot_rmse.append(rmse(mp[4], par[:,20:27]))
    tot_rmse.append(rmse(mp[5], par[:,27:34]))
    tot_rmse.append(rmse(mp[6], par[:,34:41]))
    tot_rmse.append(rmse(mp[7], par[:,41:48]))
    tot_rmse.append(rmse(mp[8], par[:,48:56]))

    tot_rmse = np.array(tot_rmse)
    if breakdown:
        return tot_rmse
    else:
        return tot_rmse.mean(axis=0)

# %%
param_error(model_params, params[(0,10,20,30,40),:], breakdown=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-b6b4c0d5e007> in <module>()
# ----> 1 param_error(model_params, params[(0,10,20,30,40),:], breakdown=False)
#
# <ipython-input-50-fc1007ef3fc5> in param_error(model_params, params, breakdown)
#      45     tot_rmse.append(rmse(mp[0], par[:,0:3]))
#      46     tot_rmse.append(rmse(mp[1], par[:,3:6]))
# ---> 47     tot_rmse.append(rmse(mp[2], par[:,6:13]))
#      48     tot_rmse.append(rmse(mp[3], par[:,13:20]))
#      49     tot_rmse.append(rmse(mp[4], par[:,20:27]))
#
# <ipython-input-50-fc1007ef3fc5> in rmse(x, y, normalize)
#       7     """
#       8     x, y = (np.array(x), np.array(y))
# ----> 9     error = y - x
#      10     if normalize == True:
#      11         mask = x != 0
#
# ValueError: operands could not be broadcast together with shapes (5,0) (7,)

# %%
good_beta = [0, 5, 10, 40, 50, 100]
beta_show = 80

plot_idx_meas = 1
plot_idx_unmeas = 2

# plot all path estimates at this beta simultaneously
fig,ax = plt.subplots(4, 1, figsize=(3.375*1.5, 3*1.5), sharex=True)
fig.set_tight_layout(True)
#plt.rc('text', usetex=True)

tplot = allpaths[beta_show, :, 0]

# plot the estimate
ax[0].plot(tplot, allpaths[beta_show, :, plot_idx_meas], color="C1", alpha=0.7, lw=1.0, label="Estimate")
# plot the true solution
ax[0].plot(tplot, true_soln[:, plot_idx_meas], color="black", lw=1.5, ls="--", label="True", alpha=0.7)
ax[0].set_xlim(tplot[0], tplot[-1])
ax[0].set_ylabel(r"Voltage")
ax[0].set_title(r"Neurodyn Model Data (beta = %d)" %beta_show)

h,l = ax[0].get_legend_handles_labels()
ax[0].legend(h,l)

# plot the estimate
ax[1].plot(tplot, allpaths[beta_show, :, 2], color="C1", alpha=0.7, lw=2.0)
# plot the true solution
ax[1].plot(tplot, true_soln[:, 2], color="black", lw=1.5, ls="--", alpha=0.7)
ax[1].set_xlim(tplot[0], tplot[-1])
ax[1].set_ylabel(r"m value")
ax[1].set_xlabel("Time")

# plot the estimate
ax[2].plot(tplot, allpaths[beta_show, :, 3], color="C1", alpha=0.7, lw=2.0)
# plot the true solution
ax[2].plot(tplot, true_soln[:, 3], color="black", lw=1.5, ls="--", alpha=0.7)
ax[2].set_xlim(tplot[0], tplot[-1])
ax[2].set_ylabel(r"h value")
ax[2].set_xlabel("Time")

# plot the estimate
ax[3].plot(tplot, allpaths[beta_show, :, 4], color="C1", alpha=0.7, lw=2.0)
# plot the true solution
ax[3].plot(tplot, true_soln[:, 4], color="black", lw=1.5, ls="--", alpha=0.7)
ax[3].set_xlim(tplot[0], tplot[-1])
ax[3].set_ylabel(r"n value")
ax[3].set_xlabel("Time")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="506">

# %% [markdown]
# #### Plot the action

# %%
#save_plot_data = False
#save_plot_data_dir = "plot_files/plot_data_action_allterms_L8_onedataset/"

fig,ax = plt.subplots(1, 3, figsize=(6.75, 2.1), sharey=True)
fig.set_tight_layout(True)

ymin = 1.0e20
ymax = 0.0

plotlw = 1.0
plotalpha = .7
#plotcolors = ["C0", "C0", "C0"]
plotcolors = ["black", "black", "black"]

action_vals = aerr[:, 1]
ax[0].plot(gammas_all[:], action_vals, lw=plotlw, color=plotcolors[0], alpha=plotalpha)
ax[0].set_xlabel(r"$\gamma$")
ax[0].set_ylabel("Action")
ax[0].axhline(y=1, lw=1, ls="--", color="C3", alpha=.7)

measerr_vals = aerr[:, 2]
ax[1].plot(gammas_all[:], measerr_vals, lw=plotlw, color=plotcolors[1], alpha=plotalpha)
ax[1].set_xlabel(r"$\gamma$")
ax[1].set_ylabel("Meas. error")

moderr_vals = aerr[:, 3]
ax[2].plot(gammas_all[:], moderr_vals, lw=plotlw, color=plotcolors[2], alpha=plotalpha)
ax[2].set_xlabel(r"$\gamma$")
ax[2].set_ylabel("Model error")

fig.suptitle("Neurodyn Model Action Levels", y=1.0)

for i in range(3):
    ax[i].set_yscale('log')
    ax[i].set_xscale('log')
#    ax[i].set_xlim(1.0e-2, 1.0e7)
#    ax[i].set_ylim(.001, 1.0e2)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="675">

# %% [markdown]
# ---
